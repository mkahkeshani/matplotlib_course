# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
val = np.linspace(0, 10, 200)
ax.plot(val, np.sin(val))
ax.axis('equal')

ax.annotate('Max Value', xy = (8, 0.8), xytext= (6, 3),arrowprops={'facecolor': 'r', 'shrink': 0.09})


plt.show()
