# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randint(150, 200, 300)
y = np.random.randint(150,200, 200)

bins = (150,160,170,180,190,200)

plt.hist(x, edgecolor = 'k',bins= bins, orientation = 'vertical', histtype = 'bar', cumulative = False, density = False, log = True)
#plt.hist(y, edgecolor = 'k',bins= bins, orientation = 'vertical')
plt.show()
